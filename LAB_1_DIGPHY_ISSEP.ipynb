# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# # LAB 1 - Digital physics

# %%
# Load the data files
import yaml
from pprint import pprint
with open("marker_data/simulated_dlo_marker_data.yaml","r") as f:
    sim_data = yaml.safe_load(f)
    
with open("marker_data/real_dlo_marker_data.yaml","r") as f:
    real_data = yaml.safe_load(f)
    
# pprint(real_data['marker_poses'])

frames = list(real_data['marker_poses'].keys())
sites = list(real_data['marker_poses']['frame_003956'].keys())

print(frames)
print(sites)

import ajx.example_environments.dlo as dlo
print(dir(dlo))
# Out:
# ['frame_003956', 'frame_004085', 'frame_004331', 'frame_004473', 'frame_004725', 'frame_005245', 'frame_006132', 'frame_006510', 'frame_007229']
# ['east_gripper', 'site_0', 'site_1', 'site_2', 'site_3', 'site_4', 'west_gripper']
# ...
